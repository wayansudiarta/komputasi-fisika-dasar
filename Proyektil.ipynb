# %% [markdown]
# # Penggunaan Sympy untuk Solusi Proyektil
#
# I Wayan Sudiarta, Ph.D.
#
# 31 Agustus 2024
#
# References:
# 1. https://docs.sympy.org/latest/tutorials/intro-tutorial/simplification.html
# 2. https://docs.sympy.org/latest/modules/plotting.html

# %%
from sympy import *
init_printing()

# %%
x, t = symbols('x y t')

# %%
v0, theta = symbols('v0 theta')
g = symbols('g')

# %%
y = (v0*sin(theta)*t -(g/2)*t**2)
eq = x - v0*cos(theta)*t

# %%
hasil = solve([eq1, eq2],[x,t])
hasil
# Out:
# ⎡        ⎛    2                           ⎞⎤
# ⎢        ⎜2⋅v₀ ⋅sin(θ)⋅cos(θ)  2⋅v₀⋅sin(θ)⎟⎥
# ⎢(0, 0), ⎜───────────────────, ───────────⎟⎥
# ⎣        ⎝         g                g     ⎠⎦

# %%
R = hasil[1][0]
T = hasil[1][1]

# %%
R, trigsimp(R)
# Out:
# ⎛    2                  2         ⎞
# ⎜2⋅v₀ ⋅sin(θ)⋅cos(θ)  v₀ ⋅sin(2⋅θ)⎟
# ⎜───────────────────, ────────────⎟
# ⎝         g                g      ⎠

# %%
v0 = 10
theta = 30*pi/180
g = 9.8
p = plot_parametric((v0*cos(theta)*t),(v0*sin(theta)*t -(g/2)*t**2), (t, 0, 1), line_color='blue')
